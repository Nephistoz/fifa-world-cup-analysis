# %% [markdown]
# # 2. Data Preprocessing
#
# ## Overview
# Clean and preprocess the FIFA World Cup data for analysis and prediction models.
#
# ### Steps:
# - Handle missing values
# - Data type conversions
# - Feature engineering
# - Normalize/scale features

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Load Raw Data

# %%
# TODO: Load raw data
# df = pd.read_csv('data/raw/matches.csv')

# %% [markdown]
# ## 2. Handle Missing Values

# %%
# TODO: Check and handle missing values
# print(df.isnull().sum())

# %% [markdown]
# ## 3. Feature Engineering

# %%
# Create new features from existing data
# TODO: Add feature engineering code
# Examples:
# - Win/Loss/Draw ratios
# - Goal difference
# - Recent form

# %% [markdown]
# ## 4. Data Normalization

# %%
# Scale features for modeling
# TODO: Add normalization code

# %% [markdown]
# ## 5. Save Processed Data

# %%
# TODO: Save processed data
# df.to_csv('data/processed/matches_processed.csv', index=False)
