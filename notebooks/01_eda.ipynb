# %% [markdown]
# # 1. Exploratory Data Analysis (EDA)
#
# ## Overview
# This notebook performs exploratory data analysis on FIFA World Cup team performance data.
#
# ### Goals:
# - Load and inspect the data
# - Identify key performance metrics
# - Visualize team statistics
# - Find patterns and correlations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for visualizations
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Load Data
#
# Load the FIFA World Cup team performance data from `data/raw/`

# %%
# TODO: Load data from data/raw/
# df = pd.read_csv('data/raw/matches.csv')
# print(df.head())
# print(df.info())
# print(df.describe())

# %% [markdown]
# ## 2. Data Overview

# %%
# Explore data structure, missing values, and basic statistics
# TODO: Add exploration code

# %% [markdown]
# ## 3. Team Performance Analysis

# %%
# Analyze team performance metrics
# TODO: Add analysis code

# %% [markdown]
# ## 4. Visualizations

# %%
# Create visualizations for key metrics
# TODO: Add visualization code
